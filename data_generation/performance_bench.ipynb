# %%
import os
import gc
import psutil
import timeit
import trimesh
import pyrender
import numpy as np

# %%
def load_step_part(filepath):
    mesh = trimesh.load_mesh(filepath)
    mesh.apply_translation(-mesh.centroid)
    mesh.apply_scale(1000)
    return mesh


def path_to_mesh(path):
    lines = []
    for entity in path.entities:
        segment = entity.discrete(path.vertices)
        for i in range(len(segment) - 1):
            lines.append(segment[i])
            lines.append(segment[i + 1])

    lines_np = np.array(lines, dtype=np.float32)

    line_mesh = pyrender.Primitive(positions=lines_np, mode=1, material=pyrender.MetallicRoughnessMaterial(baseColorFactor=(0, 0, 0)))
    return pyrender.Mesh([line_mesh])

# %%
MODEL_DIR = "models/"
IMG_SIZE = 512

step_files = [f for f in os.listdir(MODEL_DIR) if f.lower().endswith(".step")]
r = pyrender.OffscreenRenderer(512, 512)

# %%
process = psutil.Process(os.getpid())
start_time = timeit.default_timer()

meshes = []
outline_meshes = []
peak_memory_usage = -1
t_mesh_load_time = 0
t_outline_load_time = 0
t_render_time = 0
last_memory_usage = 0

for i, f in enumerate(step_files[353:]):
    try:
        i_start_time = timeit.default_timer()
        scene = pyrender.Scene(bg_color=(0.95, 0.95, 0.95, 1.0), ambient_light=(0.5, 0.5, 0.5, 1.0))
        scene.add(pyrender.PerspectiveCamera(yfov = np.pi / 3.0))
        mesh = load_step_part(os.path.join(MODEL_DIR, f))
        meshes.append(mesh)
        mesh_load_time = timeit.default_timer() - i_start_time
        t_mesh_load_time += mesh_load_time

        i2_start_time = timeit.default_timer()
        m = mesh.copy()
        m.merge_vertices()
        outline = path_to_mesh(
            trimesh.load_path(
                m.vertices[
                    m.face_adjacency_edges[
                        m.face_adjacency_angles >= np.radians(90 - max(0, min((200000 - len(m.vertices)) * 0.0005, 80)))
                    ]
                ]
            )
        )
        outline_meshes.append(outline)
        outline_load_time = timeit.default_timer() - i2_start_time
        t_outline_load_time += outline_load_time

        i3_start_time = timeit.default_timer()
        scene.add(pyrender.Mesh.from_trimesh(mesh))
        scene.add(outline)
        for _ in range(6):
            r.render(scene, flags=pyrender.RenderFlags.SKIP_CULL_FACES)
        render_time = timeit.default_timer() - i3_start_time
        t_render_time += render_time

        memory_usage = process.memory_info().rss / (1024 * 1024)
        peak_memory_usage = max(memory_usage, peak_memory_usage)

        del m
        gc.collect()
        print(f"[{i}/{len(step_files)}] Loaded {os.path.splitext(f)[0]} in {(timeit.default_timer() - i_start_time):.2f}s ({mesh_load_time:.2f} mesh / {outline_load_time:.2f} outline / {render_time:.2f} render). Current memory usage is {memory_usage:.2f} MiB, {((memory_usage - last_memory_usage) * 1024):.2f} KiB delta.")
        last_memory_usage = memory_usage
    except:
        print(f"[{i}/{len(step_files)}] Failed to load {os.path.splitext(f)[0]}")

print(f"Loaded all components in {(timeit.default_timer() - start_time):.2f}s ({t_mesh_load_time:.2f} mesh / {t_outline_load_time:.2f} outline / {t_render_time:.2f} render). Peak memory usage was {peak_memory_usage} MiB.")
# Out:
# [0/733] Loaded OpenGoRAIL48 in 7.09s (5.54 mesh / 1.04 outline / 0.36 render). Current memory usage is 2929.25 MiB, 2999552.00 KiB delta.
# [1/733] Loaded OpenGoRAIL528 in 7.09s (5.57 mesh / 1.04 outline / 0.34 render). Current memory usage is 1528.61 MiB, -1434260.00 KiB delta.
# [2/733] Loaded OpenGoRAIL624 in 7.07s (5.56 mesh / 1.02 outline / 0.35 render). Current memory usage is 1691.87 MiB, 167184.00 KiB delta.
# [3/733] Loaded OpenGoRAIL72 in 7.09s (5.61 mesh / 1.02 outline / 0.36 render). Current memory usage is 1851.14 MiB, 163092.00 KiB delta.
# [4/733] Loaded OpenGoRAIL912 in 7.14s (5.65 mesh / 1.01 outline / 0.36 render). Current memory usage is 2014.53 MiB, 167308.00 KiB delta.
# [5/733] Loaded OpenGoRAIL96 in 7.24s (5.73 mesh / 1.02 outline / 0.34 render). Current memory usage is 2177.03 MiB, 166400.00 KiB delta.
# [6/733] Loaded PaddleTire in 6.98s (4.58 mesh / 1.97 outline / 0.31 render). Current memory usage is 2251.26 MiB, 76016.00 KiB delta.
# [7/733] Loaded PatternPlate1x1H in 0.28s (0.12 mesh / 0.02 outline / 0.04 render). Current memory usage is 2073.00 MiB, -182536.00 KiB delta.
# [8/733] Loaded PatternPlate1x2H in 0.37s (0.18 mesh / 0.03 outline / 0.05 render). Current memory usage is 2074.57 MiB, 1604.00 KiB delta.
# [9/733] Loaded PatternPlate1x3H in 0.45s (0.25 mesh / 0.04 outline / 0.05 render). Current memory usage is 2076.30 MiB, 1768.00 KiB delta.
# [10/733] Loaded PatternPlate1x5H in 0.62s (0.40 mesh / 0.07 outline / 0.05 render). Current memory usage is 2080.94 MiB, 4756.00 KiB delta.
# [11/733] Loaded PatternPlate1x7H in 0.84s (0.55 mesh / 0.09 outline / 0.05 render). Current memory usage is 2090.05 MiB, 9328.00 KiB delta.
# [12/733] Loaded PatternPlate1x9H in 0.97s (0.69 mesh / 0.13 outline / 0.04 render). Current memory usage is 2100.30 MiB, 10500.00 KiB delta.
# [13/733] Loaded PatternPlateRoundEnd2H in 0.30s (0.12 mesh / 0.02 outline / 0.05 render). Current memory usage is 2095.79 MiB, -4628.00 KiB delta.
# [14/733] Loaded PatternPlateRoundEnd3H in 0.38s (0.19 mesh / 0.02 outline / 0.04 render). Current memory usage is 2095.79 MiB, 4.00 KiB delta.
# [15/733] Loaded PatternPlateRoundEnd4H in 0.43s (0.25 mesh / 0.03 outline / 0.05 render). Current memory usage is 2095.80 MiB, 8.00 KiB delta.
# [16/733] Loaded PatternPlateRoundEnd5H in 0.47s (0.26 mesh / 0.04 outline / 0.04 render). Current memory usage is 2096.95 MiB, 1176.00 KiB delta.
# [17/733] Loaded PatternPlateRoundEnd6H in 0.53s (0.30 mesh / 0.05 outline / 0.05 render). Current memory usage is 2101.04 MiB, 4192.00 KiB delta.
# [18/733] Loaded PatternPlateRoundEnd7H in 0.57s (0.36 mesh / 0.06 outline / 0.05 render). Current memory usage is 2105.77 MiB, 4840.00 KiB delta.
# [19/733] Loaded PatternSpacer12 in 2.54s (2.17 mesh / 0.15 outline / 0.12 render). Current memory usage is 2181.73 MiB, 77788.00 KiB delta.
# [20/733] Loaded PatternSpacer2 in 0.84s (0.67 mesh / 0.02 outline / 0.04 render). Current memory usage is 2138.71 MiB, -44048.00 KiB delta.
# [21/733] Loaded PatternSpacer4 in 1.06s (0.87 mesh / 0.03 outline / 0.05 render). Current memory usage is 2143.39 MiB, 4788.00 KiB delta.
# [22/733] Loaded PatternSpacer6 in 1.33s (1.10 mesh / 0.05 outline / 0.04 render). Current memory usage is 2154.31 MiB, 11180.00 KiB delta.
# [23/733] Loaded PatternSpacer8 in 1.59s (1.35 mesh / 0.07 outline / 0.05 render). Current memory usage is 2171.55 MiB, 17656.00 KiB delta.
# [24/733] Loaded PinionGear6DID15T in 1.00s (0.76 mesh / 0.08 outline / 0.05 render). Current memory usage is 2168.16 MiB, -3472.00 KiB delta.
# [25/733] Loaded PinionGear6DID20T in 0.73s (0.53 mesh / 0.03 outline / 0.05 render). Current memory usage is 2169.99 MiB, 1876.00 KiB delta.
# [26/733] Loaded PinionGear6DID24T in 0.76s (0.56 mesh / 0.03 outline / 0.05 render). Current memory usage is 2178.04 MiB, 8236.00 KiB delta.
# [27/733] Loaded PinionGear6DID30T in 0.79s (0.60 mesh / 0.04 outline / 0.05 render). Current memory usage is 2186.34 MiB, 8500.00 KiB delta.
# [28/733] Loaded PinionGear6ID15T in 0.71s (0.48 mesh / 0.02 outline / 0.05 render). Current memory usage is 2187.21 MiB, 900.00 KiB delta.
# [29/733] Loaded PinionGear6ID20T in 0.90s (0.69 mesh / 0.03 outline / 0.05 render). Current memory usage is 2194.43 MiB, 7384.00 KiB delta.
# [30/733] Loaded PinionGear6ID24T in 0.89s (0.70 mesh / 0.03 outline / 0.05 render). Current memory usage is 2201.49 MiB, 7232.00 KiB delta.
# [31/733] Loaded PinionGear6ID30T in 1.02s (0.81 mesh / 0.03 outline / 0.06 render). Current memory usage is 2208.81 MiB, 7496.00 KiB delta.
# [32/733] Loaded PinionGear8RID20T in 0.81s (0.59 mesh / 0.04 outline / 0.05 render). Current memory usage is 2218.58 MiB, 10008.00 KiB delta.
# [33/733] Loaded PinionGear8RID24T in 1.25s (1.02 mesh / 0.05 outline / 0.05 render). Current memory usage is 2229.49 MiB, 11172.00 KiB delta.
# [34/733] Loaded PinionGear8RID30T in 1.23s (1.03 mesh / 0.05 outline / 0.04 render). Current memory usage is 2238.58 MiB, 9308.00 KiB delta.
# [35/733] Loaded PinionGear8RID36T in 1.01s (0.80 mesh / 0.05 outline / 0.05 render). Current memory usage is 2250.87 MiB, 12584.00 KiB delta.
# [36/733] Loaded PinionGear8RID40T in 1.09s (0.86 mesh / 0.05 outline / 0.05 render). Current memory usage is 2262.01 MiB, 11408.00 KiB delta.
# [37/733] Loaded PinpointModule in 3.88s (3.07 mesh / 0.56 outline / 0.13 render). Current memory usage is 2419.71 MiB, 161484.00 KiB delta.
# [38/733] Loaded Post2PatternMount32-1 in 2.95s (2.71 mesh / 0.08 outline / 0.05 render). Current memory usage is 2372.96 MiB, -47876.00 KiB delta.
# [39/733] Loaded Post2PatternMount32-2 in 2.75s (2.49 mesh / 0.07 outline / 0.05 render). Current memory usage is 2384.42 MiB, 11736.00 KiB delta.
# [40/733] Loaded Pulley2P14ID60T in 2.38s (1.71 mesh / 0.48 outline / 0.07 render). Current memory usage is 2433.70 MiB, 50464.00 KiB delta.
# [41/733] Loaded Pulley2P6ID20T in 0.96s (0.75 mesh / 0.04 outline / 0.06 render). Current memory usage is 2411.09 MiB, -23156.00 KiB delta.
# [42/733] Loaded Pulley2P8RID20T in 1.37s (1.15 mesh / 0.06 outline / 0.06 render). Current memory usage is 2412.77 MiB, 1728.00 KiB delta.
# [43/733] Loaded Pulley3P14ID108T in 4.49s (3.34 mesh / 0.91 outline / 0.13 render). Current memory usage is 2564.31 MiB, 155176.00 KiB delta.
# [44/733] Loaded Pulley3P14ID36T in 0.52s (0.31 mesh / 0.03 outline / 0.05 render). Current memory usage is 2493.42 MiB, -72592.00 KiB delta.
# [45/733] Loaded Pulley3P14ID72T in 3.19s (2.30 mesh / 0.64 outline / 0.12 render). Current memory usage is 2583.89 MiB, 92636.00 KiB delta.
# [46/733] Loaded Pulley3P6DID18T in 0.87s (0.61 mesh / 0.08 outline / 0.06 render). Current memory usage is 2532.30 MiB, -52828.00 KiB delta.
# [47/733] Loaded Pulley5P14ID24T in 2.62s (2.15 mesh / 0.23 outline / 0.12 render). Current memory usage is 2608.87 MiB, 78408.00 KiB delta.
# [48/733] Loaded Pulley5P14ID48T in 3.03s (2.29 mesh / 0.51 outline / 0.11 render). Current memory usage is 2649.73 MiB, 41840.00 KiB delta.
# [49/733] Loaded Pulley5P6DID16T in 1.01s (0.72 mesh / 0.11 outline / 0.06 render). Current memory usage is 2614.71 MiB, -35856.00 KiB delta.
# [50/733] Loaded Pulley5P6ID8T in 0.63s (0.16 mesh / 0.29 outline / 0.05 render). Current memory usage is 2611.14 MiB, -3656.00 KiB delta.
# [51/733] Loaded Pulley5P6RID16T in 1.59s (1.26 mesh / 0.14 outline / 0.06 render). Current memory usage is 2632.80 MiB, 22176.00 KiB delta.
# [52/733] Loaded Pulley5P8RID24T in 2.06s (1.59 mesh / 0.23 outline / 0.09 render). Current memory usage is 2684.43 MiB, 52872.00 KiB delta.
# [53/733] Loaded Pulley8ID16T in 1.27s (0.96 mesh / 0.13 outline / 0.06 render). Current memory usage is 2674.89 MiB, -9768.00 KiB delta.
# [54/733] Loaded QuadBlockMotorMount32-1 in 8.64s (8.22 mesh / 0.23 outline / 0.08 render). Current memory usage is 2781.21 MiB, 108868.00 KiB delta.
# [55/733] Loaded QuadBlockMotorMount32-2 in 15.77s (14.66 mesh / 0.80 outline / 0.20 render). Current memory usage is 3048.95 MiB, 274168.00 KiB delta.
# [56/733] Loaded QuadBlockMotorMount43-3 in 47.79s (46.38 mesh / 1.11 outline / 0.17 render). Current memory usage is 3178.91 MiB, 133080.00 KiB delta.
# [57/733] Loaded QuadBlockPatternMount24-1 in 15.81s (15.34 mesh / 0.27 outline / 0.08 render). Current memory usage is 3135.34 MiB, -44612.00 KiB delta.
# [58/733] Loaded QuadBlockPatternMount27-1 in 13.75s (13.35 mesh / 0.19 outline / 0.06 render). Current memory usage is 3174.05 MiB, 39640.00 KiB delta.
# [59/733] Loaded QuadBlockPatternMount43-2 in 14.02s (13.61 mesh / 0.22 outline / 0.07 render). Current memory usage is 3244.14 MiB, 71764.00 KiB delta.
# [60/733] Loaded QuadBlockPatternMount43-4 in 13.36s (12.90 mesh / 0.27 outline / 0.08 render). Current memory usage is 3289.51 MiB, 46460.00 KiB delta.
# [61/733] Loaded QuadBlockPatternMount43-t5 in 7.92s (7.44 mesh / 0.28 outline / 0.07 render). Current memory usage is 3315.58 MiB, 26696.00 KiB delta.
# [62/733] Loaded RailChannel10H in 5.72s (4.20 mesh / 1.16 outline / 0.24 render). Current memory usage is 3535.90 MiB, 225612.00 KiB delta.
# [63/733] Loaded RailChannel11H in 5.83s (4.27 mesh / 1.21 outline / 0.23 render). Current memory usage is 3630.97 MiB, 97352.00 KiB delta.
# [64/733] Loaded RailChannel12H in 5.90s (4.29 mesh / 1.26 outline / 0.24 render). Current memory usage is 3729.94 MiB, 101340.00 KiB delta.
# [65/733] Loaded RailChannel13H in 6.24s (4.54 mesh / 1.32 outline / 0.25 render). Current memory usage is 3831.30 MiB, 103796.00 KiB delta.
# [66/733] Loaded RailChannel14H in 6.21s (4.48 mesh / 1.35 outline / 0.24 render). Current memory usage is 3936.96 MiB, 108200.00 KiB delta.
# [67/733] Loaded RailChannel15H in 6.42s (4.60 mesh / 1.45 outline / 0.25 render). Current memory usage is 4036.03 MiB, 101440.00 KiB delta.
# [68/733] Loaded RailChannel16H in 6.92s (4.99 mesh / 1.53 outline / 0.25 render). Current memory usage is 4142.55 MiB, 109084.00 KiB delta.
# [69/733] Loaded RailChannel17H in 6.81s (4.86 mesh / 1.57 outline / 0.24 render). Current memory usage is 4251.23 MiB, 111288.00 KiB delta.
# [70/733] Loaded RailChannel18H in 6.90s (4.91 mesh / 1.59 outline / 0.26 render). Current memory usage is 4365.40 MiB, 116904.00 KiB delta.
# [71/733] Loaded RailChannel1H in 4.96s (3.87 mesh / 0.76 outline / 0.23 render). Current memory usage is 4445.19 MiB, 81704.00 KiB delta.
# [72/733] Loaded RailChannel21H in 7.20s (5.13 mesh / 1.72 outline / 0.24 render). Current memory usage is 4573.70 MiB, 131596.00 KiB delta.
# [73/733] Loaded RailChannel25H in 8.16s (5.73 mesh / 2.04 outline / 0.26 render). Current memory usage is 4700.42 MiB, 129764.00 KiB delta.
# [74/733] Loaded RailChannel29H in 9.10s (6.51 mesh / 2.20 outline / 0.27 render). Current memory usage is 4834.84 MiB, 137648.00 KiB delta.
# [75/733] Loaded RailChannel2H in 4.85s (3.68 mesh / 0.79 outline / 0.23 render). Current memory usage is 4908.93 MiB, 75860.00 KiB delta.
# [76/733] Loaded RailChannel33H in 9.79s (6.95 mesh / 2.45 outline / 0.26 render). Current memory usage is 5076.43 MiB, 171528.00 KiB delta.
# [77/733] Loaded RailChannel37H in 11.09s (8.00 mesh / 2.70 outline / 0.26 render). Current memory usage is 5215.82 MiB, 142732.00 KiB delta.
# [78/733] Loaded RailChannel3H in 5.08s (3.90 mesh / 0.85 outline / 0.22 render). Current memory usage is 5281.34 MiB, 67096.00 KiB delta.
# [79/733] Loaded RailChannel41H in 12.32s (8.94 mesh / 2.98 outline / 0.26 render). Current memory usage is 5458.07 MiB, 180972.00 KiB delta.
# [80/733] Loaded RailChannel45H in 14.24s (10.35 mesh / 3.47 outline / 0.30 render). Current memory usage is 5611.81 MiB, 157424.00 KiB delta.
# [81/733] Loaded RailChannel49H in 16.85s (12.54 mesh / 3.88 outline / 0.29 render). Current memory usage is 5763.76 MiB, 155600.00 KiB delta.
# [82/733] Loaded RailChannel4H in 5.53s (4.17 mesh / 0.96 outline / 0.26 render). Current memory usage is 5816.80 MiB, 54316.00 KiB delta.
# [83/733] Loaded RailChannel5H in 5.75s (4.36 mesh / 1.00 outline / 0.28 render). Current memory usage is 5911.23 MiB, 96696.00 KiB delta.
# [84/733] Loaded RailChannel6H in 5.73s (4.33 mesh / 1.04 outline / 0.24 render). Current memory usage is 6007.23 MiB, 98296.00 KiB delta.
# [85/733] Loaded RailChannel7H in 6.01s (4.52 mesh / 1.09 outline / 0.25 render). Current memory usage is 6100.42 MiB, 95432.00 KiB delta.
# [86/733] Loaded RailChannel8H in 5.99s (4.45 mesh / 1.15 outline / 0.25 render). Current memory usage is 6198.21 MiB, 100140.00 KiB delta.
# [87/733] Loaded RailChannel9H in 6.06s (4.47 mesh / 1.22 outline / 0.24 render). Current memory usage is 6298.80 MiB, 103004.00 KiB delta.
# [88/733] Loaded RhinoWheel72OD in 0.94s (0.62 mesh / 0.14 outline / 0.05 render). Current memory usage is 6164.63 MiB, -137396.00 KiB delta.
# [89/733] Loaded RhinoWheel96OD in 1.10s (0.68 mesh / 0.25 outline / 0.06 render). Current memory usage is 6180.43 MiB, 16180.00 KiB delta.
# [90/733] Loaded RhinoWheel96ODThin in 1.02s (0.64 mesh / 0.21 outline / 0.06 render). Current memory usage is 6185.07 MiB, 4752.00 KiB delta.
# [91/733] Loaded Servo in 1.07s (0.73 mesh / 0.15 outline / 0.06 render). Current memory usage is 6196.29 MiB, 11488.00 KiB delta.
# [92/733] Loaded ServoGear12T in 0.46s (0.31 mesh / 0.01 outline / 0.04 render). Current memory usage is 6190.95 MiB, -5468.00 KiB delta.
# [93/733] Loaded ServoGear15T in 0.55s (0.36 mesh / 0.02 outline / 0.06 render). Current memory usage is 6190.94 MiB, -8.00 KiB delta.
# [94/733] Loaded ServoGear20T in 0.58s (0.41 mesh / 0.02 outline / 0.04 render). Current memory usage is 6191.01 MiB, 72.00 KiB delta.
# [95/733] Loaded ServoGear24T in 0.66s (0.47 mesh / 0.03 outline / 0.05 render). Current memory usage is 6191.00 MiB, -16.00 KiB delta.
# [96/733] Loaded ServoGear30T in 0.64s (0.46 mesh / 0.03 outline / 0.04 render). Current memory usage is 6190.98 MiB, -12.00 KiB delta.
# [97/733] Loaded ServoGear40T in 0.77s (0.59 mesh / 0.03 outline / 0.04 render). Current memory usage is 6196.65 MiB, 5804.00 KiB delta.
# [98/733] Loaded ServoHub8ODShaft in 6.20s (5.19 mesh / 0.69 outline / 0.19 render). Current memory usage is 6448.12 MiB, 257500.00 KiB delta.
# [99/733] Loaded ServoHubLongShaft in 1.46s (1.20 mesh / 0.06 outline / 0.05 render). Current memory usage is 6348.80 MiB, -101700.00 KiB delta.
# [100/733] Loaded ServoHubShortShaft in 1.45s (1.21 mesh / 0.06 outline / 0.05 render). Current memory usage is 6350.14 MiB, 1376.00 KiB delta.
# [101/733] Loaded ServoHubSplineShaft in 5.99s (4.82 mesh / 0.90 outline / 0.17 render). Current memory usage is 6514.44 MiB, 168240.00 KiB delta.
# [102/733] Loaded ServoPatternPlate1800 in 1.11s (0.89 mesh / 0.06 outline / 0.05 render). Current memory usage is 6429.26 MiB, -87228.00 KiB delta.
# [103/733] Loaded ServoPatternPlate1801 in 1.22s (0.91 mesh / 0.12 outline / 0.08 render). Current memory usage is 6448.01 MiB, 19200.00 KiB delta.
# [104/733] Loaded ServoPlate in 0.99s (0.81 mesh / 0.03 outline / 0.05 render). Current memory usage is 6435.81 MiB, -12492.00 KiB delta.
# [105/733] Loaded ServoShaftCoupler6ID in 0.65s (0.47 mesh / 0.03 outline / 0.05 render). Current memory usage is 6435.81 MiB, 0.00 KiB delta.
# [106/733] Loaded ServoShaftCoupler8ID in 0.80s (0.60 mesh / 0.05 outline / 0.05 render). Current memory usage is 6441.26 MiB, 5580.00 KiB delta.
# [107/733] Loaded SetScrewCollar12ID in 0.82s (0.63 mesh / 0.04 outline / 0.06 render). Current memory usage is 6437.45 MiB, -3904.00 KiB delta.
# [108/733] Loaded SetScrewCollar6ID in 0.43s (0.25 mesh / 0.02 outline / 0.05 render). Current memory usage is 6437.45 MiB, 0.00 KiB delta.
# [109/733] Loaded SetScrewCollar8ID in 0.39s (0.22 mesh / 0.02 outline / 0.04 render). Current memory usage is 6437.45 MiB, 0.00 KiB delta.
# [110/733] Loaded SetScrewCollar8RID in 0.71s (0.51 mesh / 0.04 outline / 0.05 render). Current memory usage is 6439.49 MiB, 2092.00 KiB delta.
# [111/733] Loaded SetScrewHub3ID in 1.60s (1.37 mesh / 0.07 outline / 0.06 render). Current memory usage is 6454.99 MiB, 15876.00 KiB delta.
# [112/733] Loaded SetScrewHub4ID in 1.64s (1.41 mesh / 0.07 outline / 0.06 render). Current memory usage is 6470.34 MiB, 15720.00 KiB delta.
# [113/733] Loaded SetScrewHub5ID in 1.62s (1.39 mesh / 0.07 outline / 0.06 render). Current memory usage is 6482.75 MiB, 12700.00 KiB delta.
# [114/733] Loaded SetScrewHub6ID in 1.58s (1.34 mesh / 0.07 outline / 0.07 render). Current memory usage is 6492.35 MiB, 9836.00 KiB delta.
# [115/733] Loaded SetScrewSprocket6DID10T in 0.51s (0.35 mesh / 0.02 outline / 0.05 render). Current memory usage is 6487.91 MiB, -4548.00 KiB delta.
# [116/733] Loaded SetScrewSprocket8RID10T in 0.65s (0.47 mesh / 0.04 outline / 0.04 render). Current memory usage is 6494.89 MiB, 7152.00 KiB delta.
# [117/733] Loaded SetScrewSprocket8RID14T in 0.70s (0.51 mesh / 0.05 outline / 0.04 render). Current memory usage is 6505.59 MiB, 10956.00 KiB delta.
# [118/733] Loaded Shaft12ROD104 in 3.69s (1.99 mesh / 1.45 outline / 0.13 render). Current memory usage is 6623.73 MiB, 120972.00 KiB delta.
# [119/733] Loaded Shaft12ROD112 in 3.71s (1.98 mesh / 1.48 outline / 0.14 render). Current memory usage is 6670.22 MiB, 47608.00 KiB delta.
# [120/733] Loaded Shaft12ROD120 in 3.68s (1.99 mesh / 1.45 outline / 0.15 render). Current memory usage is 6717.79 MiB, 48704.00 KiB delta.
# [121/733] Loaded Shaft12ROD1200 in 3.60s (1.92 mesh / 1.43 outline / 0.13 render). Current memory usage is 6764.86 MiB, 48200.00 KiB delta.
# [122/733] Loaded Shaft12ROD144 in 3.65s (1.93 mesh / 1.45 outline / 0.14 render). Current memory usage is 6812.21 MiB, 48492.00 KiB delta.
# [123/733] Loaded Shaft12ROD192 in 3.66s (1.98 mesh / 1.45 outline / 0.13 render). Current memory usage is 6858.92 MiB, 47828.00 KiB delta.
# [124/733] Loaded Shaft12ROD240 in 3.66s (1.95 mesh / 1.45 outline / 0.13 render). Current memory usage is 6905.04 MiB, 47224.00 KiB delta.
# [125/733] Loaded Shaft12ROD288 in 3.64s (1.93 mesh / 1.46 outline / 0.13 render). Current memory usage is 6951.39 MiB, 47472.00 KiB delta.
# [126/733] Loaded Shaft12ROD336 in 3.65s (1.93 mesh / 1.45 outline / 0.13 render). Current memory usage is 6997.21 MiB, 46912.00 KiB delta.
# [127/733] Loaded Shaft12ROD384 in 3.62s (1.92 mesh / 1.43 outline / 0.14 render). Current memory usage is 7043.92 MiB, 47836.00 KiB delta.
# [128/733] Loaded Shaft12ROD43 in 3.64s (1.92 mesh / 1.48 outline / 0.13 render). Current memory usage is 7092.18 MiB, 49420.00 KiB delta.
# [129/733] Loaded Shaft12ROD432 in 3.64s (1.93 mesh / 1.45 outline / 0.14 render). Current memory usage is 7138.79 MiB, 47728.00 KiB delta.
# [130/733] Loaded Shaft12ROD48 in 3.71s (1.98 mesh / 1.47 outline / 0.13 render). Current memory usage is 7185.98 MiB, 48320.00 KiB delta.
# [131/733] Loaded Shaft12ROD528 in 3.65s (1.94 mesh / 1.47 outline / 0.13 render). Current memory usage is 7233.29 MiB, 48444.00 KiB delta.
# [132/733] Loaded Shaft12ROD56 in 3.70s (1.98 mesh / 1.47 outline / 0.13 render). Current memory usage is 7280.84 MiB, 48688.00 KiB delta.
# [133/733] Loaded Shaft12ROD624 in 3.65s (1.94 mesh / 1.45 outline / 0.13 render). Current memory usage is 7328.42 MiB, 48724.00 KiB delta.
# [134/733] Loaded Shaft12ROD64 in 3.70s (1.97 mesh / 1.46 outline / 0.15 render). Current memory usage is 7375.26 MiB, 47968.00 KiB delta.
# [135/733] Loaded Shaft12ROD72 in 3.70s (1.96 mesh / 1.49 outline / 0.13 render). Current memory usage is 7421.03 MiB, 46864.00 KiB delta.
# [136/733] Loaded Shaft12ROD80 in 3.69s (1.95 mesh / 1.47 outline / 0.14 render). Current memory usage is 7467.67 MiB, 47764.00 KiB delta.
# [137/733] Loaded Shaft12ROD88 in 3.68s (1.94 mesh / 1.47 outline / 0.13 render). Current memory usage is 7514.45 MiB, 47904.00 KiB delta.
# [138/733] Loaded Shaft12ROD96 in 3.74s (1.99 mesh / 1.48 outline / 0.15 render). Current memory usage is 7561.58 MiB, 48256.00 KiB delta.
# [139/733] Loaded Side1Post1Bore4PillowBlock in 0.78s (0.50 mesh / 0.10 outline / 0.06 render). Current memory usage is 7507.50 MiB, -55380.00 KiB delta.
# [140/733] Loaded Side1Post1Bore6PillowBlock in 0.62s (0.35 mesh / 0.09 outline / 0.06 render). Current memory usage is 7511.43 MiB, 4028.00 KiB delta.
# [141/733] Loaded Side1Post1Bore8PillowBlock in 0.61s (0.34 mesh / 0.10 outline / 0.05 render). Current memory usage is 7519.00 MiB, 7756.00 KiB delta.
# [142/733] Failed to load Side1Post1ClampingMount12ID
# [143/733] Failed to load Side1Post1ClampingMount15ID
# [144/733] Failed to load Side1Post1ClampingMount21ID
# [145/733] Failed to load Side1Post1ClampingMount6ID
# [146/733] Failed to load Side1Post1ClampingMount8ID
# [147/733] Loaded Side1Post1PillowBlock8RID in 0.80s (0.52 mesh / 0.10 outline / 0.06 render). Current memory usage is 7611.44 MiB, 94656.00 KiB delta.
# [148/733] Loaded Side1Post2ClampingMount12ID in 1.34s (1.09 mesh / 0.07 outline / 0.05 render). Current memory usage is 7593.63 MiB, -18240.00 KiB delta.
# [149/733] Loaded Side1Post2ClampingMount14ID in 1.78s (1.25 mesh / 0.35 outline / 0.07 render). Current memory usage is 7613.27 MiB, 20108.00 KiB delta.
# [150/733] Loaded Side1Post2ClampingMount15ID in 1.31s (1.05 mesh / 0.08 outline / 0.05 render). Current memory usage is 7621.21 MiB, 8140.00 KiB delta.
# [151/733] Loaded Side1Post2ClampingMount21ID in 1.29s (1.05 mesh / 0.07 outline / 0.05 render). Current memory usage is 7630.47 MiB, 9480.00 KiB delta.
# [152/733] Loaded Side1Post2ClampingMount22ID in 1.32s (1.07 mesh / 0.08 outline / 0.05 render). Current memory usage is 7642.68 MiB, 12500.00 KiB delta.
# [153/733] Loaded Side1Post2ClampingMount25ID in 1.31s (1.07 mesh / 0.07 outline / 0.05 render). Current memory usage is 7654.78 MiB, 12392.00 KiB delta.
# [154/733] Loaded Side1Post2ClampingMount32ID in 1.81s (1.29 mesh / 0.33 outline / 0.06 render). Current memory usage is 7684.09 MiB, 30012.00 KiB delta.
# [155/733] Loaded Side1Post2ClampingMount36ID in 2.25s (1.67 mesh / 0.39 outline / 0.07 render). Current memory usage is 7713.90 MiB, 30528.00 KiB delta.
# [156/733] Loaded Side1Post2ClampingMount37ID in 1.29s (1.05 mesh / 0.07 outline / 0.05 render). Current memory usage is 7712.83 MiB, -1100.00 KiB delta.
# [157/733] Loaded Side1Post2ClampingMount6ID in 1.27s (1.01 mesh / 0.07 outline / 0.06 render). Current memory usage is 7726.79 MiB, 14300.00 KiB delta.
# [158/733] Loaded Side1Post2ClampingMount8ID in 1.30s (1.07 mesh / 0.07 outline / 0.06 render). Current memory usage is 7738.19 MiB, 11668.00 KiB delta.
# [159/733] Loaded Side1Post2PatternMount24-1 in 1.93s (1.68 mesh / 0.09 outline / 0.05 render). Current memory usage is 7756.86 MiB, 19116.00 KiB delta.
# [160/733] Loaded Side1Post2PatternMount32-1 in 1.95s (1.69 mesh / 0.09 outline / 0.06 render). Current memory usage is 7775.20 MiB, 18780.00 KiB delta.
# [161/733] Loaded Side1Post2PillowBlock12ID in 0.90s (0.63 mesh / 0.11 outline / 0.05 render). Current memory usage is 7780.31 MiB, 5236.00 KiB delta.
# [162/733] Loaded Side1Post2PillowBlock32ID in 0.78s (0.55 mesh / 0.06 outline / 0.05 render). Current memory usage is 7778.65 MiB, -1696.00 KiB delta.
# [163/733] Loaded Side1Post2PillowBlock4ID in 1.08s (0.78 mesh / 0.11 outline / 0.07 render). Current memory usage is 7798.75 MiB, 20576.00 KiB delta.
# [164/733] Loaded Side1Post2PillowBlock6ID in 0.85s (0.57 mesh / 0.11 outline / 0.06 render). Current memory usage is 7803.68 MiB, 5048.00 KiB delta.
# [165/733] Loaded Side1Post2PillowBlock8ID in 1.09s (0.78 mesh / 0.12 outline / 0.06 render). Current memory usage is 7818.82 MiB, 15508.00 KiB delta.
# [166/733] Loaded Side1Post2PillowBlock8RID in 1.07s (0.79 mesh / 0.12 outline / 0.06 render). Current memory usage is 7834.05 MiB, 15600.00 KiB delta.
# [167/733] Failed to load Side2Post1ClampingMount12ID
# [168/733] Failed to load Side2Post1ClampingMount14ID
# [169/733] Failed to load Side2Post1ClampingMount6ID
# [170/733] Failed to load Side2Post1ClampingMount8ID
# [171/733] Loaded Side2Post1PillowBlock4ID in 1.77s (1.49 mesh / 0.12 outline / 0.06 render). Current memory usage is 7933.82 MiB, 102164.00 KiB delta.
# [172/733] Loaded Side2Post1PillowBlock6ID in 0.87s (0.60 mesh / 0.09 outline / 0.06 render). Current memory usage is 7914.71 MiB, -19572.00 KiB delta.
# [173/733] Loaded Side2Post1PillowBlock8ID in 1.77s (1.46 mesh / 0.13 outline / 0.05 render). Current memory usage is 7917.35 MiB, 2704.00 KiB delta.
# [174/733] Loaded Side2Post1PillowBlock8RID in 1.80s (1.48 mesh / 0.13 outline / 0.05 render). Current memory usage is 7928.13 MiB, 11036.00 KiB delta.
# [175/733] Loaded Side2Post2ClampingMount22ID in 3.77s (2.95 mesh / 0.60 outline / 0.09 render). Current memory usage is 7997.37 MiB, 70904.00 KiB delta.
# [176/733] Loaded Side2Post2ClampingMount32ID in 7.16s (4.18 mesh / 2.74 outline / 0.11 render). Current memory usage is 8067.02 MiB, 71320.00 KiB delta.
# [177/733] Loaded Side2Post2ClampingMount36ID in 7.17s (4.27 mesh / 2.67 outline / 0.11 render). Current memory usage is 8114.50 MiB, 48624.00 KiB delta.
# [178/733] Loaded Side2Post2PillowBlock32ID in 2.59s (2.30 mesh / 0.09 outline / 0.05 render). Current memory usage is 8077.25 MiB, -38144.00 KiB delta.
# [179/733] Loaded SingleServoArm in 0.33s (0.15 mesh / 0.01 outline / 0.04 render). Current memory usage is 8073.13 MiB, -4224.00 KiB delta.
# [180/733] Loaded SonicHub14DID in 5.24s (3.67 mesh / 1.23 outline / 0.20 render). Current memory usage is 8236.30 MiB, 167088.00 KiB delta.
# [181/733] Loaded SonicHub14ID in 5.22s (3.68 mesh / 1.25 outline / 0.18 render). Current memory usage is 8298.95 MiB, 64148.00 KiB delta.
# [182/733] Loaded SonicHub4ID in 5.72s (3.68 mesh / 1.76 outline / 0.16 render). Current memory usage is 8368.09 MiB, 70808.00 KiB delta.
# [183/733] Loaded SonicHub5ID in 5.16s (3.62 mesh / 1.25 outline / 0.17 render). Current memory usage is 8440.07 MiB, 73704.00 KiB delta.
# [184/733] Loaded SonicHub6DID in 5.27s (3.71 mesh / 1.27 outline / 0.17 render). Current memory usage is 8506.99 MiB, 68528.00 KiB delta.
# [185/733] Loaded SonicHub6ID in 5.25s (3.68 mesh / 1.26 outline / 0.18 render). Current memory usage is 8579.14 MiB, 73880.00 KiB delta.
# [186/733] Loaded SonicHub8ID in 5.26s (3.68 mesh / 1.28 outline / 0.17 render). Current memory usage is 8647.95 MiB, 70464.00 KiB delta.
# [187/733] Loaded SonicHub8RID in 5.26s (3.72 mesh / 1.25 outline / 0.18 render). Current memory usage is 8717.56 MiB, 71276.00 KiB delta.
# [188/733] Loaded Spacer6ID8OD12 in 0.23s (0.05 mesh / 0.00 outline / 0.05 render). Current memory usage is 8616.02 MiB, -103980.00 KiB delta.
# [189/733] Loaded Spacer6ID8OD2 in 0.21s (0.05 mesh / 0.00 outline / 0.04 render). Current memory usage is 8616.02 MiB, 4.00 KiB delta.
# [190/733] Loaded Spacer6ID8OD4 in 0.21s (0.05 mesh / 0.01 outline / 0.04 render). Current memory usage is 8616.02 MiB, 0.00 KiB delta.
# [191/733] Loaded Spacer6ID8OD6 in 0.22s (0.05 mesh / 0.00 outline / 0.05 render). Current memory usage is 8616.02 MiB, 0.00 KiB delta.
# [192/733] Loaded Spacer6ID8OD8 in 0.21s (0.05 mesh / 0.00 outline / 0.05 render). Current memory usage is 8616.02 MiB, 0.00 KiB delta.
# [193/733] Loaded Spacer8ID10OD12 in 0.22s (0.05 mesh / 0.00 outline / 0.05 render). Current memory usage is 8616.02 MiB, 0.00 KiB delta.
# [194/733] Loaded Spacer8ID10OD2 in 0.20s (0.04 mesh / 0.00 outline / 0.04 render). Current memory usage is 8616.02 MiB, 0.00 KiB delta.
# [195/733] Loaded Spacer8ID10OD4 in 0.23s (0.05 mesh / 0.01 outline / 0.04 render). Current memory usage is 8616.02 MiB, 0.00 KiB delta.
# [196/733] Loaded Spacer8ID10OD6 in 0.21s (0.05 mesh / 0.01 outline / 0.04 render). Current memory usage is 8616.02 MiB, 0.00 KiB delta.
# [197/733] Loaded Spacer8ID10OD8 in 0.21s (0.05 mesh / 0.01 outline / 0.05 render). Current memory usage is 8616.02 MiB, 0.00 KiB delta.
# [198/733] Loaded Spacer8RID12ROD12 in 0.21s (0.05 mesh / 0.00 outline / 0.04 render). Current memory usage is 8616.02 MiB, 0.00 KiB delta.
# [199/733] Loaded Spacer8RID12ROD16 in 0.20s (0.05 mesh / 0.00 outline / 0.05 render). Current memory usage is 8616.02 MiB, 0.00 KiB delta.
# [200/733] Loaded Spacer8RID12ROD8 in 0.20s (0.04 mesh / 0.00 outline / 0.04 render). Current memory usage is 8616.02 MiB, 0.00 KiB delta.
# [201/733] Loaded SquareBeam10H in 1.68s (1.46 mesh / 0.06 outline / 0.05 render). Current memory usage is 8633.06 MiB, 17452.00 KiB delta.
# [202/733] Loaded SquareBeam11H in 1.69s (1.49 mesh / 0.05 outline / 0.04 render). Current memory usage is 8642.96 MiB, 10140.00 KiB delta.
# [203/733] Loaded SquareBeam12H in 1.67s (1.46 mesh / 0.06 outline / 0.05 render). Current memory usage is 8650.62 MiB, 7840.00 KiB delta.
# [204/733] Loaded SquareBeam13H in 1.77s (1.55 mesh / 0.06 outline / 0.05 render). Current memory usage is 8660.12 MiB, 9728.00 KiB delta.
# [205/733] Loaded SquareBeam15H in 1.75s (1.52 mesh / 0.07 outline / 0.05 render). Current memory usage is 8669.40 MiB, 9500.00 KiB delta.
# [206/733] Loaded SquareBeam17H in 1.82s (1.56 mesh / 0.09 outline / 0.05 render). Current memory usage is 8679.84 MiB, 10688.00 KiB delta.
# [207/733] Loaded SquareBeam19H in 1.86s (1.57 mesh / 0.09 outline / 0.04 render). Current memory usage is 8691.84 MiB, 12288.00 KiB delta.
# [208/733] Loaded SquareBeam21H in 1.88s (1.59 mesh / 0.10 outline / 0.05 render). Current memory usage is 8704.55 MiB, 13016.00 KiB delta.
# [209/733] Loaded SquareBeam23H in 1.82s (1.54 mesh / 0.10 outline / 0.05 render). Current memory usage is 8717.21 MiB, 12968.00 KiB delta.
# [210/733] Loaded SquareBeam29H in 1.98s (1.63 mesh / 0.13 outline / 0.05 render). Current memory usage is 8733.28 MiB, 16456.00 KiB delta.
# [211/733] Loaded SquareBeam2H in 1.26s (1.07 mesh / 0.02 outline / 0.07 render). Current memory usage is 8731.43 MiB, -1892.00 KiB delta.
# [212/733] Loaded SquareBeam35H in 2.06s (1.72 mesh / 0.17 outline / 0.05 render). Current memory usage is 8757.56 MiB, 26752.00 KiB delta.
# [213/733] Loaded SquareBeam3H in 1.74s (1.55 mesh / 0.03 outline / 0.04 render). Current memory usage is 8758.27 MiB, 728.00 KiB delta.
# [214/733] Loaded SquareBeam41H in 2.29s (1.90 mesh / 0.21 outline / 0.05 render). Current memory usage is 8783.96 MiB, 26308.00 KiB delta.
# [215/733] Loaded SquareBeam4H in 1.68s (1.46 mesh / 0.03 outline / 0.05 render). Current memory usage is 8782.75 MiB, -1236.00 KiB delta.
# [216/733] Loaded SquareBeam5H in 1.66s (1.44 mesh / 0.04 outline / 0.05 render). Current memory usage is 8787.68 MiB, 5040.00 KiB delta.
# [217/733] Loaded SquareBeam6H in 1.72s (1.49 mesh / 0.04 outline / 0.06 render). Current memory usage is 8795.57 MiB, 8084.00 KiB delta.
# [218/733] Loaded SquareBeam7H in 1.75s (1.54 mesh / 0.06 outline / 0.05 render). Current memory usage is 8803.58 MiB, 8200.00 KiB delta.
# [219/733] Loaded SquareBeam8H in 1.68s (1.48 mesh / 0.05 outline / 0.06 render). Current memory usage is 8809.82 MiB, 6396.00 KiB delta.
# [220/733] Loaded SquareBeam9H in 1.66s (1.45 mesh / 0.05 outline / 0.05 render). Current memory usage is 8820.14 MiB, 10568.00 KiB delta.
# [221/733] Loaded SquarePatternThreadedPlate16P in 0.87s (0.68 mesh / 0.03 outline / 0.05 render). Current memory usage is 8819.12 MiB, -1052.00 KiB delta.
# [222/733] Loaded SquarePatternThreadedPlate32P in 0.86s (0.66 mesh / 0.03 outline / 0.05 render). Current memory usage is 8820.85 MiB, 1772.00 KiB delta.
# [223/733] Loaded Standoff6OD10 in 0.65s (0.47 mesh / 0.02 outline / 0.06 render). Current memory usage is 8824.57 MiB, 3816.00 KiB delta.
# [224/733] Loaded Standoff6OD11 in 0.72s (0.51 mesh / 0.04 outline / 0.06 render). Current memory usage is 8832.27 MiB, 7876.00 KiB delta.
# [225/733] Loaded Standoff6OD12 in 0.98s (0.69 mesh / 0.12 outline / 0.06 render). Current memory usage is 8845.14 MiB, 13188.00 KiB delta.
# [226/733] Loaded Standoff6OD14 in 3.88s (1.46 mesh / 2.20 outline / 0.10 render). Current memory usage is 8896.48 MiB, 52564.00 KiB delta.
# [227/733] Loaded Standoff6OD16 in 1.52s (1.02 mesh / 0.31 outline / 0.07 render). Current memory usage is 8887.71 MiB, -8972.00 KiB delta.
# [228/733] Loaded Standoff6OD18 in 1.27s (1.01 mesh / 0.10 outline / 0.07 render). Current memory usage is 8900.39 MiB, 12976.00 KiB delta.
# [229/733] Loaded Standoff6OD19 in 1.31s (0.97 mesh / 0.15 outline / 0.06 render). Current memory usage is 8908.44 MiB, 8244.00 KiB delta.
# [230/733] Loaded Standoff6OD20 in 1.28s (1.02 mesh / 0.10 outline / 0.07 render). Current memory usage is 8920.26 MiB, 12104.00 KiB delta.
# [231/733] Loaded Standoff6OD22 in 1.59s (1.25 mesh / 0.15 outline / 0.07 render). Current memory usage is 8935.99 MiB, 16112.00 KiB delta.
# [232/733] Loaded Standoff6OD24 in 1.03s (0.80 mesh / 0.03 outline / 0.08 render). Current memory usage is 8930.07 MiB, -6064.00 KiB delta.
# [233/733] Loaded Standoff6OD26 in 1.08s (0.82 mesh / 0.04 outline / 0.07 render). Current memory usage is 8932.98 MiB, 2976.00 KiB delta.
# [234/733] Loaded Standoff6OD27 in 1.05s (0.85 mesh / 0.04 outline / 0.06 render). Current memory usage is 8939.56 MiB, 6744.00 KiB delta.
# [235/733] Loaded Standoff6OD28 in 1.01s (0.81 mesh / 0.03 outline / 0.06 render). Current memory usage is 8945.02 MiB, 5592.00 KiB delta.
# [236/733] Loaded Standoff6OD3 in 0.37s (0.21 mesh / 0.01 outline / 0.06 render). Current memory usage is 8943.80 MiB, -1248.00 KiB delta.
# [237/733] Loaded Standoff6OD30 in 1.02s (0.82 mesh / 0.03 outline / 0.05 render). Current memory usage is 8951.44 MiB, 7816.00 KiB delta.
# [238/733] Loaded Standoff6OD32 in 1.00s (0.80 mesh / 0.03 outline / 0.07 render). Current memory usage is 8957.43 MiB, 6132.00 KiB delta.
# [239/733] Loaded Standoff6OD34 in 1.01s (0.81 mesh / 0.03 outline / 0.07 render). Current memory usage is 8962.33 MiB, 5024.00 KiB delta.
# [240/733] Loaded Standoff6OD36 in 1.01s (0.79 mesh / 0.04 outline / 0.06 render). Current memory usage is 8967.96 MiB, 5764.00 KiB delta.
# [241/733] Loaded Standoff6OD38 in 1.01s (0.80 mesh / 0.04 outline / 0.06 render). Current memory usage is 8974.00 MiB, 6180.00 KiB delta.
# [242/733] Loaded Standoff6OD4 in 0.41s (0.24 mesh / 0.01 outline / 0.05 render). Current memory usage is 8973.20 MiB, -816.00 KiB delta.
# [243/733] Loaded Standoff6OD40 in 1.01s (0.80 mesh / 0.04 outline / 0.06 render). Current memory usage is 8979.70 MiB, 6660.00 KiB delta.
# [244/733] Loaded Standoff6OD42 in 1.03s (0.82 mesh / 0.03 outline / 0.06 render). Current memory usage is 8984.82 MiB, 5244.00 KiB delta.
# [245/733] Loaded Standoff6OD43 in 0.99s (0.80 mesh / 0.03 outline / 0.06 render). Current memory usage is 8991.74 MiB, 7080.00 KiB delta.
# [246/733] Loaded Standoff6OD44 in 1.00s (0.81 mesh / 0.03 outline / 0.06 render). Current memory usage is 8998.45 MiB, 6868.00 KiB delta.
# [247/733] Loaded Standoff6OD46 in 1.00s (0.80 mesh / 0.03 outline / 0.07 render). Current memory usage is 9004.70 MiB, 6408.00 KiB delta.
# [248/733] Loaded Standoff6OD48 in 0.99s (0.80 mesh / 0.03 outline / 0.05 render). Current memory usage is 9010.93 MiB, 6372.00 KiB delta.
# [249/733] Loaded Standoff6OD5 in 0.46s (0.28 mesh / 0.01 outline / 0.06 render). Current memory usage is 9009.71 MiB, -1244.00 KiB delta.
# [250/733] Loaded Standoff6OD50 in 0.96s (0.75 mesh / 0.03 outline / 0.07 render). Current memory usage is 9017.56 MiB, 8036.00 KiB delta.
# [251/733] Loaded Standoff6OD52 in 0.99s (0.81 mesh / 0.03 outline / 0.06 render). Current memory usage is 9024.00 MiB, 6600.00 KiB delta.
# [252/733] Loaded Standoff6OD54 in 1.32s (1.12 mesh / 0.03 outline / 0.05 render). Current memory usage is 9029.21 MiB, 5332.00 KiB delta.
# [253/733] Loaded Standoff6OD56 in 1.01s (0.82 mesh / 0.03 outline / 0.06 render). Current memory usage is 9034.03 MiB, 4936.00 KiB delta.
# [254/733] Loaded Standoff6OD58 in 1.23s (1.04 mesh / 0.03 outline / 0.05 render). Current memory usage is 9040.59 MiB, 6716.00 KiB delta.
# [255/733] Loaded Standoff6OD6 in 0.47s (0.30 mesh / 0.01 outline / 0.06 render). Current memory usage is 9039.39 MiB, -1224.00 KiB delta.
# [256/733] Loaded Standoff6OD60 in 1.23s (1.04 mesh / 0.03 outline / 0.06 render). Current memory usage is 9047.49 MiB, 8292.00 KiB delta.
# [257/733] Loaded Standoff6OD7 in 0.51s (0.34 mesh / 0.02 outline / 0.06 render). Current memory usage is 9046.33 MiB, -1188.00 KiB delta.
# [258/733] Loaded Standoff6OD8 in 0.65s (0.46 mesh / 0.01 outline / 0.06 render). Current memory usage is 9047.84 MiB, 1540.00 KiB delta.
# [259/733] Loaded Standoff6OD9 in 0.67s (0.49 mesh / 0.02 outline / 0.06 render). Current memory usage is 9052.45 MiB, 4720.00 KiB delta.
# [260/733] Loaded Standoff8RID10 in 0.65s (0.46 mesh / 0.03 outline / 0.05 render). Current memory usage is 9057.50 MiB, 5180.00 KiB delta.
# [261/733] Loaded Standoff8RID12 in 1.02s (0.69 mesh / 0.16 outline / 0.06 render). Current memory usage is 9074.90 MiB, 17812.00 KiB delta.
# [262/733] Loaded Standoff8RID120 in 0.97s (0.76 mesh / 0.04 outline / 0.06 render). Current memory usage is 9080.15 MiB, 5380.00 KiB delta.
# [263/733] Loaded Standoff8RID14 in 3.59s (1.27 mesh / 2.11 outline / 0.09 render). Current memory usage is 9134.94 MiB, 56104.00 KiB delta.
# [264/733] Loaded Standoff8RID144 in 0.99s (0.77 mesh / 0.04 outline / 0.07 render). Current memory usage is 9111.57 MiB, -23932.00 KiB delta.
# [265/733] Loaded Standoff8RID16 in 1.04s (0.83 mesh / 0.04 outline / 0.05 render). Current memory usage is 9114.68 MiB, 3180.00 KiB delta.
# [266/733] Loaded Standoff8RID168 in 0.96s (0.74 mesh / 0.04 outline / 0.06 render). Current memory usage is 9123.09 MiB, 8620.00 KiB delta.
# [267/733] Loaded Standoff8RID18 in 1.11s (0.92 mesh / 0.03 outline / 0.06 render). Current memory usage is 9130.50 MiB, 7588.00 KiB delta.
# [268/733] Loaded Standoff8RID19 in 1.19s (0.94 mesh / 0.08 outline / 0.06 render). Current memory usage is 9152.80 MiB, 22832.00 KiB delta.
# [269/733] Loaded Standoff8RID192 in 0.97s (0.75 mesh / 0.04 outline / 0.06 render). Current memory usage is 9152.10 MiB, -720.00 KiB delta.
# [270/733] Loaded Standoff8RID20 in 1.15s (0.93 mesh / 0.03 outline / 0.06 render). Current memory usage is 9155.64 MiB, 3628.00 KiB delta.
# [271/733] Loaded Standoff8RID216 in 0.99s (0.77 mesh / 0.04 outline / 0.06 render). Current memory usage is 9164.24 MiB, 8804.00 KiB delta.
# [272/733] Loaded Standoff8RID22 in 1.36s (1.13 mesh / 0.04 outline / 0.06 render). Current memory usage is 9169.64 MiB, 5528.00 KiB delta.
# [273/733] Loaded Standoff8RID24 in 0.99s (0.78 mesh / 0.04 outline / 0.06 render). Current memory usage is 9177.75 MiB, 8312.00 KiB delta.
# [274/733] Loaded Standoff8RID240 in 1.02s (0.77 mesh / 0.04 outline / 0.07 render). Current memory usage is 9185.36 MiB, 7792.00 KiB delta.
# [275/733] Loaded Standoff8RID26 in 0.99s (0.77 mesh / 0.04 outline / 0.06 render). Current memory usage is 9193.05 MiB, 7872.00 KiB delta.
# [276/733] Loaded Standoff8RID264 in 0.97s (0.77 mesh / 0.04 outline / 0.06 render). Current memory usage is 9200.46 MiB, 7588.00 KiB delta.
# [277/733] Loaded Standoff8RID27 in 0.99s (0.77 mesh / 0.05 outline / 0.07 render). Current memory usage is 9206.79 MiB, 6476.00 KiB delta.
# [278/733] Loaded Standoff8RID28 in 0.98s (0.76 mesh / 0.05 outline / 0.06 render). Current memory usage is 9214.25 MiB, 7648.00 KiB delta.
# [279/733] Loaded Standoff8RID288 in 0.98s (0.77 mesh / 0.04 outline / 0.06 render). Current memory usage is 9220.80 MiB, 6700.00 KiB delta.
# [280/733] Loaded Standoff8RID30 in 0.98s (0.77 mesh / 0.04 outline / 0.06 render). Current memory usage is 9228.53 MiB, 7916.00 KiB delta.
# [281/733] Loaded Standoff8RID32 in 0.99s (0.76 mesh / 0.04 outline / 0.07 render). Current memory usage is 9235.74 MiB, 7384.00 KiB delta.
# [282/733] Loaded Standoff8RID36 in 0.96s (0.74 mesh / 0.04 outline / 0.07 render). Current memory usage is 9243.34 MiB, 7784.00 KiB delta.
# [283/733] Loaded Standoff8RID40 in 0.99s (0.78 mesh / 0.04 outline / 0.06 render). Current memory usage is 9251.28 MiB, 8128.00 KiB delta.
# [284/733] Loaded Standoff8RID43 in 1.01s (0.78 mesh / 0.05 outline / 0.06 render). Current memory usage is 9258.06 MiB, 6948.00 KiB delta.
# [285/733] Loaded Standoff8RID48 in 1.00s (0.79 mesh / 0.05 outline / 0.06 render). Current memory usage is 9265.12 MiB, 7224.00 KiB delta.
# [286/733] Loaded Standoff8RID50 in 0.99s (0.77 mesh / 0.05 outline / 0.06 render). Current memory usage is 9272.76 MiB, 7828.00 KiB delta.
# [287/733] Loaded Standoff8RID56 in 1.01s (0.78 mesh / 0.04 outline / 0.07 render). Current memory usage is 9279.54 MiB, 6944.00 KiB delta.
# [288/733] Loaded Standoff8RID6 in 0.53s (0.33 mesh / 0.02 outline / 0.06 render). Current memory usage is 9276.05 MiB, -3572.00 KiB delta.
# [289/733] Loaded Standoff8RID64 in 1.04s (0.78 mesh / 0.05 outline / 0.07 render). Current memory usage is 9289.35 MiB, 13616.00 KiB delta.
# [290/733] Loaded Standoff8RID72 in 0.99s (0.76 mesh / 0.04 outline / 0.06 render). Current memory usage is 9296.95 MiB, 7780.00 KiB delta.
# [291/733] Loaded Standoff8RID8 in 0.59s (0.41 mesh / 0.02 outline / 0.06 render). Current memory usage is 9294.17 MiB, -2844.00 KiB delta.
# [292/733] Loaded Standoff8RID80 in 0.98s (0.77 mesh / 0.04 outline / 0.06 render). Current memory usage is 9307.64 MiB, 13792.00 KiB delta.
# [293/733] Loaded Standoff8RID88 in 0.99s (0.76 mesh / 0.04 outline / 0.06 render). Current memory usage is 9315.72 MiB, 8276.00 KiB delta.
# [294/733] Loaded Standoff8RID96 in 1.03s (0.81 mesh / 0.04 outline / 0.06 render). Current memory usage is 9322.55 MiB, 6988.00 KiB delta.
# [295/733] Loaded SteelChannelConnectorPlate in 0.90s (0.69 mesh / 0.03 outline / 0.06 render). Current memory usage is 9323.16 MiB, 624.00 KiB delta.
# [296/733] Loaded SteelClampingSprocket12RID in 5.51s (3.02 mesh / 2.18 outline / 0.17 render). Current memory usage is 9496.86 MiB, 177868.00 KiB delta.
# [297/733] Loaded SteelClampingSprocket8RID in 1.94s (1.50 mesh / 0.22 outline / 0.09 render). Current memory usage is 9469.21 MiB, -28312.00 KiB delta.
# [298/733] Loaded SteelGridPlate3x7H in 0.30s (0.10 mesh / 0.02 outline / 0.06 render). Current memory usage is 9432.75 MiB, -37328.00 KiB delta.
# [299/733] Loaded SteelGridPlate5x7H in 0.40s (0.17 mesh / 0.03 outline / 0.06 render). Current memory usage is 9432.75 MiB, -8.00 KiB delta.
# [300/733] Loaded SteelGussetPlate in 0.28s (0.09 mesh / 0.01 outline / 0.06 render). Current memory usage is 9432.74 MiB, -4.00 KiB delta.
# [301/733] Loaded SteelHubMountSprocket14ID in 2.43s (2.05 mesh / 0.17 outline / 0.08 render). Current memory usage is 9475.10 MiB, 43372.00 KiB delta.
# [302/733] Loaded ThreadedLBracket1H in 0.57s (0.40 mesh / 0.01 outline / 0.04 render). Current memory usage is 9454.67 MiB, -20920.00 KiB delta.
# [303/733] Loaded ThreadedLBracket3H in 1.14s (0.94 mesh / 0.03 outline / 0.05 render). Current memory usage is 9455.65 MiB, 1008.00 KiB delta.
# [304/733] Loaded ThreadedLBracket5H in 1.74s (1.51 mesh / 0.06 outline / 0.06 render). Current memory usage is 9474.09 MiB, 18884.00 KiB delta.
# [305/733] Loaded ThreadedPlate1x3H in 0.75s (0.53 mesh / 0.02 outline / 0.06 render). Current memory usage is 9472.79 MiB, -1336.00 KiB delta.
# [306/733] Loaded ThreadedPlate1x5H in 1.06s (0.86 mesh / 0.03 outline / 0.08 render). Current memory usage is 9475.19 MiB, 2460.00 KiB delta.
# [307/733] Loaded ThreadedPlate2x3H in 1.24s (1.04 mesh / 0.04 outline / 0.06 render). Current memory usage is 9483.06 MiB, 8060.00 KiB delta.
# [308/733] Loaded ThruHolePillowBlock10ID in 0.45s (0.19 mesh / 0.09 outline / 0.05 render). Current memory usage is 9490.69 MiB, 7808.00 KiB delta.
# [309/733] Loaded ThruHolePillowBlock12ID in 0.54s (0.25 mesh / 0.11 outline / 0.05 render). Current memory usage is 9499.39 MiB, 8916.00 KiB delta.
# [310/733] Loaded ThruHolePillowBlock4ID in 0.46s (0.19 mesh / 0.08 outline / 0.07 render). Current memory usage is 9500.97 MiB, 1616.00 KiB delta.
# [311/733] Loaded ThruHolePillowBlock6ID in 0.45s (0.19 mesh / 0.08 outline / 0.05 render). Current memory usage is 9508.23 MiB, 7432.00 KiB delta.
# [312/733] Loaded ThruHolePillowBlock8ID in 0.48s (0.18 mesh / 0.11 outline / 0.05 render). Current memory usage is 9515.85 MiB, 7804.00 KiB delta.
# [313/733] Loaded ThrustBearing12ID in 0.80s (0.25 mesh / 0.36 outline / 0.08 render). Current memory usage is 9548.81 MiB, 33752.00 KiB delta.
# [314/733] Loaded ThrustBearing6ID in 0.62s (0.20 mesh / 0.21 outline / 0.07 render). Current memory usage is 9554.25 MiB, 5568.00 KiB delta.
# [315/733] Loaded ThrustBearing8ID in 0.69s (0.20 mesh / 0.27 outline / 0.08 render). Current memory usage is 9571.69 MiB, 17860.00 KiB delta.
# [316/733] Loaded UBeam10H in 0.32s (0.12 mesh / 0.02 outline / 0.04 render). Current memory usage is 9556.73 MiB, -15324.00 KiB delta.
# [317/733] Loaded UBeam11H in 0.33s (0.13 mesh / 0.03 outline / 0.05 render). Current memory usage is 9556.73 MiB, 0.00 KiB delta.
# [318/733] Loaded UBeam12H in 0.34s (0.14 mesh / 0.03 outline / 0.06 render). Current memory usage is 9556.72 MiB, -4.00 KiB delta.
# [319/733] Loaded UBeam13H in 0.33s (0.13 mesh / 0.03 outline / 0.04 render). Current memory usage is 9558.97 MiB, 2300.00 KiB delta.
# [320/733] Loaded UBeam15H in 0.36s (0.15 mesh / 0.04 outline / 0.04 render). Current memory usage is 9560.82 MiB, 1896.00 KiB delta.
# [321/733] Loaded UBeam17H in 0.37s (0.16 mesh / 0.04 outline / 0.05 render). Current memory usage is 9565.76 MiB, 5060.00 KiB delta.
# [322/733] Loaded UBeam19H in 0.41s (0.18 mesh / 0.06 outline / 0.05 render). Current memory usage is 9569.02 MiB, 3340.00 KiB delta.
# [323/733] Loaded UBeam1H in 0.22s (0.06 mesh / 0.00 outline / 0.04 render). Current memory usage is 9569.02 MiB, 0.00 KiB delta.
# [324/733] Loaded UBeam21H in 0.45s (0.20 mesh / 0.07 outline / 0.05 render). Current memory usage is 9574.28 MiB, 5384.00 KiB delta.
# [325/733] Loaded UBeam23H in 0.43s (0.20 mesh / 0.07 outline / 0.05 render). Current memory usage is 9579.36 MiB, 5204.00 KiB delta.
# [326/733] Loaded UBeam29H in 0.51s (0.27 mesh / 0.08 outline / 0.05 render). Current memory usage is 9586.07 MiB, 6872.00 KiB delta.
# [327/733] Loaded UBeam2H in 0.29s (0.07 mesh / 0.01 outline / 0.05 render). Current memory usage is 9584.95 MiB, -1156.00 KiB delta.
# [328/733] Loaded UBeam35H in 0.55s (0.29 mesh / 0.10 outline / 0.05 render). Current memory usage is 9596.30 MiB, 11632.00 KiB delta.
# [329/733] Loaded UBeam3H in 0.25s (0.07 mesh / 0.01 outline / 0.05 render). Current memory usage is 9594.95 MiB, -1392.00 KiB delta.
# [330/733] Loaded UBeam41H in 0.71s (0.40 mesh / 0.13 outline / 0.05 render). Current memory usage is 9607.52 MiB, 12876.00 KiB delta.
# [331/733] Loaded UBeam4H in 0.25s (0.07 mesh / 0.01 outline / 0.05 render). Current memory usage is 9603.80 MiB, -3804.00 KiB delta.
# [332/733] Loaded UBeam5H in 0.27s (0.09 mesh / 0.01 outline / 0.04 render). Current memory usage is 9603.80 MiB, 0.00 KiB delta.
# [333/733] Loaded UBeam6H in 0.28s (0.09 mesh / 0.02 outline / 0.05 render). Current memory usage is 9603.80 MiB, 0.00 KiB delta.
# [334/733] Loaded UBeam7H in 0.27s (0.10 mesh / 0.02 outline / 0.05 render). Current memory usage is 9603.83 MiB, 24.00 KiB delta.
# [335/733] Loaded UBeam8H in 0.29s (0.09 mesh / 0.02 outline / 0.04 render). Current memory usage is 9603.83 MiB, 0.00 KiB delta.
# [336/733] Loaded UBeam9H in 0.31s (0.11 mesh / 0.02 outline / 0.05 render). Current memory usage is 9604.57 MiB, 760.00 KiB delta.
# [337/733] Loaded UBracket32Bore in 0.33s (0.12 mesh / 0.03 outline / 0.04 render). Current memory usage is 9606.55 MiB, 2032.00 KiB delta.
# [338/733] Loaded UBracketRoundEnd in 0.54s (0.31 mesh / 0.06 outline / 0.04 render). Current memory usage is 9616.61 MiB, 10296.00 KiB delta.
# [339/733] Loaded UChannel10H in 2.96s (1.98 mesh / 0.78 outline / 0.08 render). Current memory usage is 9701.29 MiB, 86708.00 KiB delta.
# [340/733] Loaded UChannel11H in 3.24s (2.16 mesh / 0.90 outline / 0.08 render). Current memory usage is 9749.64 MiB, 49520.00 KiB delta.
# [341/733] Loaded UChannel12H in 3.81s (2.48 mesh / 1.10 outline / 0.10 render). Current memory usage is 9796.15 MiB, 47620.00 KiB delta.
# [342/733] Loaded UChannel13H in 4.20s (2.74 mesh / 1.25 outline / 0.09 render). Current memory usage is 9842.55 MiB, 47516.00 KiB delta.
# [343/733] Loaded UChannel14H in 4.60s (2.99 mesh / 1.35 outline / 0.10 render). Current memory usage is 9889.77 MiB, 48348.00 KiB delta.
# [344/733] Loaded UChannel15H in 5.02s (3.25 mesh / 1.53 outline / 0.11 render). Current memory usage is 9942.61 MiB, 54108.00 KiB delta.
# [345/733] Loaded UChannel16H in 5.50s (3.56 mesh / 1.70 outline / 0.12 render). Current memory usage is 10003.85 MiB, 62716.00 KiB delta.
# [346/733] Loaded UChannel17H in 5.91s (3.82 mesh / 1.85 outline / 0.11 render). Current memory usage is 10060.69 MiB, 58200.00 KiB delta.
# [347/733] Loaded UChannel18H in 6.78s (4.37 mesh / 2.18 outline / 0.12 render). Current memory usage is 10118.23 MiB, 58924.00 KiB delta.
# [348/733] Loaded UChannel1H in 0.49s (0.26 mesh / 0.06 outline / 0.05 render). Current memory usage is 10062.48 MiB, -57088.00 KiB delta.
# [349/733] Loaded UChannel21H in 8.19s (5.06 mesh / 2.85 outline / 0.13 render). Current memory usage is 10208.59 MiB, 149612.00 KiB delta.
# [350/733] Loaded UChannel25H in 11.14s (6.61 mesh / 4.23 outline / 0.15 render). Current memory usage is 10312.68 MiB, 106596.00 KiB delta.
# [351/733] Loaded UChannel29H in 13.51s (8.09 mesh / 5.13 outline / 0.16 render). Current memory usage is 10429.12 MiB, 119228.00 KiB delta.
# [352/733] Loaded UChannel2H in 0.71s (0.43 mesh / 0.11 outline / 0.05 render). Current memory usage is 10337.80 MiB, -93512.00 KiB delta.
# [353/733] Loaded UChannel33H in 16.44s (9.57 mesh / 6.55 outline / 0.17 render). Current memory usage is 10560.36 MiB, 227904.00 KiB delta.
# [354/733] Loaded UChannel37H in 22.15s (11.31 mesh / 10.51 outline / 0.21 render). Current memory usage is 10695.15 MiB, 138028.00 KiB delta.
# [355/733] Loaded UChannel3H in 0.92s (0.57 mesh / 0.18 outline / 0.06 render). Current memory usage is 10585.26 MiB, -112532.00 KiB delta.
# [356/733] Loaded UChannel41H in 26.04s (13.24 mesh / 12.48 outline / 0.20 render). Current memory usage is 10851.72 MiB, 272860.00 KiB delta.
# [357/733] Loaded UChannel45H in 30.43s (15.17 mesh / 14.89 outline / 0.23 render). Current memory usage is 11011.92 MiB, 164040.00 KiB delta.
# [358/733] Loaded UChannel49H in 35.32s (17.69 mesh / 17.27 outline / 0.23 render). Current memory usage is 11181.22 MiB, 173364.00 KiB delta.
# [359/733] Loaded UChannel4H in 1.18s (0.76 mesh / 0.24 outline / 0.05 render). Current memory usage is 11037.82 MiB, -146840.00 KiB delta.
# [360/733] Loaded UChannel5H in 1.42s (0.92 mesh / 0.33 outline / 0.06 render). Current memory usage is 11054.12 MiB, 16692.00 KiB delta.
# [361/733] Loaded UChannel6H in 1.77s (1.14 mesh / 0.41 outline / 0.08 render). Current memory usage is 11072.79 MiB, 19116.00 KiB delta.
# [362/733] Loaded UChannel7H in 2.06s (1.37 mesh / 0.49 outline / 0.07 render). Current memory usage is 11087.89 MiB, 15460.00 KiB delta.
# [363/733] Loaded UChannel8H in 2.41s (1.58 mesh / 0.59 outline / 0.07 render). Current memory usage is 11109.98 MiB, 22620.00 KiB delta.
# [364/733] Loaded UChannel9H in 2.69s (1.78 mesh / 0.70 outline / 0.08 render). Current memory usage is 11130.46 MiB, 20972.00 KiB delta.
# [365/733] Loaded USBCamera in 3.47s (2.54 mesh / 0.63 outline / 0.15 render). Current memory usage is 11211.34 MiB, 82824.00 KiB delta.
# [366/733] Loaded UWheel4ID in 0.58s (0.16 mesh / 0.20 outline / 0.07 render). Current memory usage is 11167.97 MiB, -44412.00 KiB delta.
# [367/733] Loaded UWheel6ID in 0.50s (0.15 mesh / 0.16 outline / 0.07 render). Current memory usage is 11177.85 MiB, 10116.00 KiB delta.
# [368/733] Loaded UWheel8ID in 0.57s (0.16 mesh / 0.20 outline / 0.07 render). Current memory usage is 11190.76 MiB, 13224.00 KiB delta.
# [369/733] Loaded UWheel8RID in 0.56s (0.18 mesh / 0.19 outline / 0.06 render). Current memory usage is 11201.93 MiB, 11432.00 KiB delta.
# [370/733] Loaded VGuide1200 in 0.30s (0.11 mesh / 0.00 outline / 0.05 render). Current memory usage is 11188.88 MiB, -13360.00 KiB delta.
# [371/733] Loaded VGuide288 in 0.31s (0.12 mesh / 0.00 outline / 0.06 render). Current memory usage is 11188.88 MiB, 0.00 KiB delta.
# [372/733] Loaded VGuide624 in 0.30s (0.12 mesh / 0.00 outline / 0.05 render). Current memory usage is 11188.88 MiB, 0.00 KiB delta.
# [373/733] Loaded VGuideLeadScrewDollyKit in 10.87s (8.12 mesh / 1.92 outline / 0.69 render). Current memory usage is 12003.33 MiB, 833996.00 KiB delta.
# [374/733] Failed to load ViperSlide10Ball
# [375/733] Loaded ViperSlide14Ball in 1.83s (1.35 mesh / 0.26 outline / 0.09 render). Current memory usage is 11596.88 MiB, -416208.00 KiB delta.
# [376/733] Loaded VWheel in 0.44s (0.13 mesh / 0.14 outline / 0.06 render). Current memory usage is 11568.89 MiB, -28660.00 KiB delta.
# [377/733] Loaded WormGearSet6ID in 4.26s (3.48 mesh / 0.54 outline / 0.09 render). Current memory usage is 11612.63 MiB, 44792.00 KiB delta.
# [378/733] Loaded WormGearSet8RID in 5.04s (3.58 mesh / 1.23 outline / 0.11 render). Current memory usage is 11635.57 MiB, 23492.00 KiB delta.
# [379/733] Loaded WWheel in 0.51s (0.15 mesh / 0.17 outline / 0.06 render). Current memory usage is 11609.40 MiB, -26796.00 KiB delta.
# Loaded all components in 1057.43s (754.19 mesh / 224.59 outline / 33.91 render). Peak memory usage was 12003.328125 MiB.

# %%
m = load_step_part(os.path.join(MODEL_DIR, step_files[357]))

# %%
path = trimesh.load_path(
    m.vertices[
        m.face_adjacency_edges[
            m.face_adjacency_angles
            >= np.radians(90 - max(0, min((200000 - len(m.vertices)) * 0.0005, 80)))
        ]
    ]
)

# %%
m_path = path_to_mesh(path)
